# %% [markdown]
# ### Forecast Spectral Indices
#
# This notebook demonstrates how to use the `ForecastTS` class to forecast spectral indices using XGBoost. It includes steps for loading the data, preprocessing, training the model, and visualizing the forecasts.

# %%
# import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from scripts.process_ts import DataAnalysis
from scripts.forecast_ts import ForecastTS
from scripts.read_bucket import DataReader

# %%
# Load the data
# Area of interest
aoi_name = "atamah_camp"
country_name = "syria"

data_reader = DataReader(country_name)
ts_data = data_reader.read_ts(aoi_name)
print(f"{aoi_name.replace('_', ' ').title()}: {ts_data.shape}")
ts_data.head(n=2)
# Out:
# Time series loaded: (423, 10)
# Atamah Camp: (423, 10)
#                      time      ndvi       bsi      ndmi       nbr  \
# 0 2018-03-12 08:29:03.369  0.426711 -0.001167  0.087464  0.221377
# 1 2018-03-12 08:29:51.297  0.434007  0.004068  0.087596  0.222577
#
#       aoi_name country                                           geometry  \
# 0  atamah_camp   syria  [1, 3, 0, 0, 0, 1, 0, 0, 0, 5, 0, 0, 0, 86, 59...
# 1  atamah_camp   syria  [1, 3, 0, 0, 0, 1, 0, 0, 0, 5, 0, 0, 0, 86, 59...
#
#                                         geometry_wkt  bbox_area
# 0  POLYGON ((36.732521110322224 36.27396741081821...   0.006417
# 1  POLYGON ((36.732521110322224 36.27396741081821...   0.006417

# %% [markdown]
# Let's plot the raw data and see what it looks like.

# %%
# define a color palette for the plots
cmap = plt.get_cmap("BrBG")
colors = cmap(np.linspace(0, 1, 12))

# %%
raw_data = ts_data.copy()
raw_data.set_index('time', inplace=True)
raw_data.sort_index(inplace=True)

# %%
fig, ax = plt.subplots(4, 1, figsize=(11, 13))

sns.scatterplot(x='time', y='ndvi',
            data=raw_data,
            color=colors[8],
            alpha=0.6,
            marker='o',
            s=10,
            label='Raw NDVI data',
            ax=ax[0])

sns.scatterplot(x='time', y='bsi',
            data=raw_data,
            color=colors[8],
            alpha=0.6,
            marker='o',
            s=10,
            label='Raw BSI data',
            ax=ax[1])

sns.scatterplot(x='time', y='ndmi',
            data=raw_data,
            color=colors[8],
            alpha=0.6,
            marker='o',
            s=10,
            label='Raw NDMI data',
            ax=ax[2])

sns.scatterplot(x='time', y='nbr',
            data=raw_data,
            color=colors[8],
            alpha=0.6,
            marker='o',
            s=10,
            label='Raw NBR data',
            ax=ax[3])

sns.despine()

ax[0].set_title(f"Raw Indices Time Series - {aoi_name.replace('_', ' ').title()}")
ax[0].set_xlabel("Time")
ax[0].set_ylabel("NDVI")
ax[0].legend(loc='upper left')

ax[1].set_xlabel("Time")
ax[1].set_ylabel("BSI")
ax[1].legend(loc='upper left')

ax[2].set_xlabel("Time")
ax[2].set_ylabel("NDMI")
ax[2].legend(loc='upper left')

ax[3].set_xlabel("Time")
ax[3].set_ylabel("NBR")
ax[3].legend(loc='upper left')

# %% [markdown]
# The data shows a clear seasonal pattern, with peaks and troughs corresponding to the growing season. We can also see some noise in the data, which is not uncommon in this type of data. Another important thing to note is that the spacing of the data points is not regular. This requires some work on preprocessing the data before it is fed into the forecasting model.

# %%
# Perform preprocessing: resmpling, interpolation, and smoothing

da = DataAnalysis()
spec_indices = ['ndvi', 'bsi', 'ndmi', 'nbr']

proc_ts = da.preprocess_time_series(spec_indices, ts_data)
print(proc_ts.shape)
proc_ts.head(n=2)
# Out:
# (440, 4)
#             ndvi_smooth  bsi_smooth  ndmi_smooth  nbr_smooth
# time
# 2018-03-18     0.430359    0.001450     0.087530    0.221977
# 2018-03-25     0.423546    0.002039     0.088046    0.222902

# %%
fig, ax = plt.subplots(4, 1, figsize=(11, 13))

sns.scatterplot(x='time', y='ndvi',
            data=raw_data,
            color=colors[8],
            alpha=0.6,
            marker='o',
            s=10,
            label='Raw NDVI data',
            ax=ax[0])

sns.lineplot(x='time', y='ndvi_smooth',
            data=proc_ts,
            lw=1,
            color=colors[0],
            label='Processed NDVI data',
            ax=ax[0])

sns.scatterplot(x='time', y='bsi',
            data=raw_data,
            color=colors[8],
            alpha=0.6,
            marker='o',
            s=10,
            label='Raw BSI data',
            ax=ax[1])

sns.lineplot(x='time', y='bsi_smooth',
            data=proc_ts,
            lw=1,
            color=colors[0],
            label='Processed BSI data',
            ax=ax[1])

sns.scatterplot(x='time', y='ndmi',
            data=raw_data,
            color=colors[8],
            alpha=0.6,
            marker='o',
            s=10,
            label='Raw NDMI data',
            ax=ax[2])

sns.lineplot(x='time', y='ndmi_smooth',
            data=proc_ts,
            lw=1,
            color=colors[0],
            label='Processed NDMI data',
            ax=ax[2])

sns.scatterplot(x='time', y='nbr',
            data=raw_data,
            color=colors[8],
            alpha=0.6,
            marker='o',
            s=10,
            label='Raw NBR data',
            ax=ax[3])

sns.lineplot(x='time', y='nbr_smooth',
            data=proc_ts,
            lw=1,
            color=colors[0],
            label='Processed NBR data',
            ax=ax[3])

sns.despine()

ax[0].set_title(f"Raw Indices Time Series - {aoi_name.replace('_', ' ').title()}")
ax[0].set_xlabel("Time")
ax[0].set_ylabel("NDVI")
ax[0].legend(loc='upper left', fontsize=8)

ax[1].set_xlabel("Time")
ax[1].set_ylabel("BSI")
ax[1].legend(loc='upper left', fontsize=8)

ax[2].set_xlabel("Time")
ax[2].set_ylabel("NDMI")
ax[2].legend(loc='upper left', fontsize=8)

ax[3].set_xlabel("Time")
ax[3].set_ylabel("NBR")
ax[3].legend(loc='upper left', fontsize=8)

# %% [markdown]
# Now, the data is ready to be fed into the forecasting model. We will use the `ForecastTS` class to train an XGBoost model on the data and make forecasts for the next 8 weeks.
#
# The `ForecastTS` class performs hyperparameter tuning using `Optuna` and cross-validation to find the best parameters for the XGBoost model. This is important for many reasons, including avoiding overfitting (the model memorizes the training data instead of learning general patterns) and improving the model's performance on unseen data. After training the model, we will visualize the forecasts and compare them to the actual data to see how well the model is performing.
#
# The `ForecastTS` class also includes functionality for logging the model and its parameters to `MLflow`, which is a great tool for tracking machine learning experiments and models. This allows us to keep track of different runs, compare models, and easily deploy the best model in production.

# %%
# instantiate the forecasting class. The aoi_name is used for logging the model and its parameters in MLflow.
forecast_ts = ForecastTS(aoi_name=aoi_name,
                         country=country_name)
# Out:
# c:\Users\aycha\miniconda3\envs\geospatial\Lib\site-packages\mlflow\tracking\_tracking_service\utils.py:184: FutureWarning: The filesystem tracking backend (e.g., './mlruns') is deprecated as of February 2026. Consider transitioning to a database backend (e.g., 'sqlite:///mlflow.db') to take advantage of the latest MLflow features. See https://mlflow.org/docs/latest/self-hosting/migrate-from-file-store for migration guidance.
#   return FileStore(store_uri, store_uri)
# 2026/08/25 15:55:26 INFO mlflow.tracking.fluent: Experiment with name 'atamah_camp_2026-08-25_19-55' does not exist. Creating a new experiment.

# %% [markdown]
# In this step we format the input data in the format required by the forecasting model. The `unique_id` column is used to identify the time series (NDVI, BSI, etc.), and the `ds` column is used to identify the time column

# %%
input_df = forecast_ts.format_input_data(proc_ts)
input_df.head()
# Out:
#           ds         y unique_id
# 0 2018-03-18  0.430359      ndvi
# 1 2018-03-25  0.426953      ndvi
# 2 2018-04-01  0.416734      ndvi
# 3 2018-04-08  0.406630      ndvi
# 4 2018-04-15  0.401792      ndvi

# %% [markdown]
# Now, we split the available data into a training set and a test set. The training set is used to train the model, while the test set is used to evaluate the model's performance on unseen data. We will use the last 12 weeks of data as the test set, and the rest of the data as the training set.

# %%
h= 12 # forecast horizon (number of weeks to forecast)

# make sure the data is sorted by date for each unique_id (i.e., each spectral index.)
input_df.sort_values(by=['unique_id', 'ds'], inplace=True)

train_dfs = []
test_dfs = []
for i in list(input_df['unique_id'].unique()):
    temp_train = input_df[input_df['unique_id'] == i].iloc[:-h]
    temp_test = input_df[input_df['unique_id'] == i].iloc[-h:]
    print(f"Unique ID {i} - Train shape: {temp_train.shape}, Test shape: {temp_test.shape}")

    train_dfs.append(temp_train)
    test_dfs.append(temp_test)

train_df = pd.concat(train_dfs)
test_df = pd.concat(test_dfs)

print("Train shape:", train_df.shape)
print("Test shape:", test_df.shape)
# Out:
# Unique ID bsi - Train shape: (428, 3), Test shape: (12, 3)
# Unique ID nbr - Train shape: (428, 3), Test shape: (12, 3)
# Unique ID ndmi - Train shape: (428, 3), Test shape: (12, 3)
# Unique ID ndvi - Train shape: (428, 3), Test shape: (12, 3)
# Train shape: (1712, 3)
# Test shape: (48, 3)

# %% [markdown]
# Now train the model and keep only the best fit. The model will be save so it can be used later for inference. The best model is determined based on the mean absolute error (MAE) on the cross-validation sets. The model with the lowest MAE is selected as the best model.

# %%
preds = forecast_ts.forecast_xgb(input_df, h)
# Out:
# [I 2026-08-25 15:55:48,195] A new study created in memory with name: no-name-0cf85615-08e0-4574-84dc-00e9a8a987f8
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2026-08-25 15:55:49,290] Trial 0 finished with value: 0.04954512252313887 and parameters: {'n_estimators': 286, 'max_depth': 3, 'learning_rate': 0.0260059276568097, 'subsample': 0.7540775932740076, 'colsample_bytree': 0.6217728762235426}. Best is trial 0 with value: 0.04954512252313887.
# [I 2026-08-25 15:55:50,009] Trial 1 finished with value: 0.05023614389008597 and parameters: {'n_estimators': 182, 'max_depth': 5, 'learning_rate': 0.12079254997188481, 'subsample': 0.8688169004824, 'colsample_bytree': 0.6863689436812557}. Best is trial 0 with value: 0.04954512252313887.
# [I 2026-08-25 15:55:51,008] Trial 2 finished with value: 0.04830606574008319 and parameters: {'n_estimators': 624, 'max_depth': 3, 'learning_rate': 0.028654445250048278, 'subsample': 0.9614009952800118, 'colsample_bytree': 0.5779000511127617}. Best is trial 2 with value: 0.04830606574008319.
# [I 2026-08-25 15:55:53,617] Trial 3 finished with value: 0.04449135986942565 and parameters: {'n_estimators': 898, 'max_depth': 6, 'learning_rate': 0.010578630773034272, 'subsample': 0.7690312483769419, 'colsample_bytree': 0.8074924556096293}. Best is trial 3 with value: 0.04449135986942565.
# [I 2026-08-25 15:55:54,694] Trial 4 finished with value: 0.06188079962238488 and parameters: {'n_estimators': 137, 'max_depth': 9, 'learning_rate': 0.016038166146731023, 'subsample': 0.637952303196155, 'colsample_bytree': 0.7036541373321878}. Best is trial 3 with value: 0.04449135986942565.
# [I 2026-08-25 15:55:55,799] Trial 5 finished with value: 0.04392212267667775 and parameters: {'n_estimators': 202, 'max_depth': 7, 'learning_rate': 0.06155272404475331, 'subsample': 0.5195994989330674, 'colsample_bytree': 0.5244541642101751}. Best is trial 5 with value: 0.04392212267667775.
# [I 2026-08-25 15:55:56,663] Trial 6 finished with value: 0.04768042363624166 and parameters: {'n_estimators': 355, 'max_depth': 3, 'learning_rate': 0.031471520293778456, 'subsample': 0.8203772101850983, 'colsample_bytree': 0.9171157830551382}. Best is trial 5 with value: 0.04392212267667775.
# [I 2026-08-25 15:55:58,219] Trial 7 finished with value: 0.044562132333036665 and parameters: {'n_estimators': 436, 'max_depth': 6, 'learning_rate': 0.05671692034753874, 'subsample': 0.8138344134296325, 'colsample_bytree': 0.8238972402863272}. Best is trial 5 with value: 0.04392212267667775.
# [I 2026-08-25 15:56:00,592] Trial 8 finished with value: 0.05157838782017481 and parameters: {'n_estimators': 384, 'max_depth': 10, 'learning_rate': 0.03842451124187533, 'subsample': 0.9821691616814452, 'colsample_bytree': 0.7869985013878047}. Best is trial 5 with value: 0.04392212267667775.
# [I 2026-08-25 15:56:02,016] Trial 9 finished with value: 0.043180756348495684 and parameters: {'n_estimators': 964, 'max_depth': 6, 'learning_rate': 0.12820990013865988, 'subsample': 0.9183612926220603, 'colsample_bytree': 0.8369947161577036}. Best is trial 9 with value: 0.043180756348495684.
# [I 2026-08-25 15:56:03,190] Trial 10 finished with value: 0.04320163324882742 and parameters: {'n_estimators': 981, 'max_depth': 7, 'learning_rate': 0.2795869991427975, 'subsample': 0.8986239048145708, 'colsample_bytree': 0.9654356637029993}. Best is trial 9 with value: 0.043180756348495684.
# [I 2026-08-25 15:56:04,307] Trial 11 finished with value: 0.0505662728181859 and parameters: {'n_estimators': 970, 'max_depth': 8, 'learning_rate': 0.2712182087719299, 'subsample': 0.9014219524581722, 'colsample_bytree': 0.9636620469301366}. Best is trial 9 with value: 0.043180756348495684.
# [I 2026-08-25 15:56:05,352] Trial 12 finished with value: 0.05036107948560837 and parameters: {'n_estimators': 784, 'max_depth': 5, 'learning_rate': 0.26357334779519204, 'subsample': 0.9123958254520347, 'colsample_bytree': 0.896407704205276}. Best is trial 9 with value: 0.043180756348495684.
# [I 2026-08-25 15:56:06,696] Trial 13 finished with value: 0.04516953623533482 and parameters: {'n_estimators': 743, 'max_depth': 8, 'learning_rate': 0.14893654004916895, 'subsample': 0.656347412043736, 'colsample_bytree': 0.9810262656703207}. Best is trial 9 with value: 0.043180756348495684.
# [I 2026-08-25 15:56:07,908] Trial 14 finished with value: 0.04236016279436525 and parameters: {'n_estimators': 980, 'max_depth': 5, 'learning_rate': 0.12854685216670406, 'subsample': 0.988657692361293, 'colsample_bytree': 0.8669408215840224}. Best is trial 14 with value: 0.04236016279436525.
# [I 2026-08-25 15:56:09,128] Trial 15 finished with value: 0.0414626961790216 and parameters: {'n_estimators': 825, 'max_depth': 5, 'learning_rate': 0.10912309767423178, 'subsample': 0.981898089004108, 'colsample_bytree': 0.8622960523815522}. Best is trial 15 with value: 0.0414626961790216.
# [I 2026-08-25 15:56:10,321] Trial 16 finished with value: 0.046860669455782045 and parameters: {'n_estimators': 801, 'max_depth': 4, 'learning_rate': 0.10140929546549561, 'subsample': 0.9865795134879422, 'colsample_bytree': 0.8871966605333114}. Best is trial 15 with value: 0.0414626961790216.
# [I 2026-08-25 15:56:11,601] Trial 17 finished with value: 0.04443334753401965 and parameters: {'n_estimators': 626, 'max_depth': 5, 'learning_rate': 0.07778533441389959, 'subsample': 0.6742805810630661, 'colsample_bytree': 0.7435636558392589}. Best is trial 15 with value: 0.0414626961790216.
# [I 2026-08-25 15:56:12,733] Trial 18 finished with value: 0.04741105998174236 and parameters: {'n_estimators': 823, 'max_depth': 4, 'learning_rate': 0.1759108787791413, 'subsample': 0.843502905421577, 'colsample_bytree': 0.8664886107474313}. Best is trial 15 with value: 0.0414626961790216.
# [I 2026-08-25 15:56:13,750] Trial 19 finished with value: 0.04838350522792704 and parameters: {'n_estimators': 539, 'max_depth': 4, 'learning_rate': 0.0853794107359307, 'subsample': 0.9438467241713616, 'colsample_bytree': 0.7575380746080991}. Best is trial 15 with value: 0.0414626961790216.
# [I 2026-08-25 15:56:14,954] Trial 20 finished with value: 0.05199335817436198 and parameters: {'n_estimators': 692, 'max_depth': 5, 'learning_rate': 0.18879973631238867, 'subsample': 0.5111766101349602, 'colsample_bytree': 0.9380273860755973}. Best is trial 15 with value: 0.0414626961790216.
# [I 2026-08-25 15:56:16,070] Trial 21 finished with value: 0.04412700030297856 and parameters: {'n_estimators': 904, 'max_depth': 6, 'learning_rate': 0.12446725619506763, 'subsample': 0.9927632246866156, 'colsample_bytree': 0.817164835825659}. Best is trial 15 with value: 0.0414626961790216.
# [I 2026-08-25 15:56:17,190] Trial 22 finished with value: 0.0469076562809884 and parameters: {'n_estimators': 889, 'max_depth': 7, 'learning_rate': 0.18789468327765974, 'subsample': 0.9371635221024519, 'colsample_bytree': 0.8615444347491961}. Best is trial 15 with value: 0.0414626961790216.
# [I 2026-08-25 15:56:18,747] Trial 23 finished with value: 0.04443617807313179 and parameters: {'n_estimators': 983, 'max_depth': 6, 'learning_rate': 0.07552516246737064, 'subsample': 0.8667452664164431, 'colsample_bytree': 0.8389488747150253}. Best is trial 15 with value: 0.0414626961790216.
# [I 2026-08-25 15:56:20,013] Trial 24 finished with value: 0.04646098669804309 and parameters: {'n_estimators': 873, 'max_depth': 4, 'learning_rate': 0.10758307502895885, 'subsample': 0.9380389901295997, 'colsample_bytree': 0.7576140783823233}. Best is trial 15 with value: 0.0414626961790216.
# [I 2026-08-25 15:56:21,015] Trial 25 finished with value: 0.0475689178339154 and parameters: {'n_estimators': 713, 'max_depth': 5, 'learning_rate': 0.15594144062962687, 'subsample': 0.9987517800646354, 'colsample_bytree': 0.9215598622121651}. Best is trial 15 with value: 0.0414626961790216.
# [I 2026-08-25 15:56
. Best is trial 42 with value: 0.04013936428843105.
# [I 2026-08-25 15:57:42,738] Trial 68 finished with value: 0.04698389682547107 and parameters: {'n_estimators': 592, 'max_depth': 9, 'learning_rate': 0.1355375728847928, 'subsample': 0.9964688944837766, 'colsample_bytree': 0.8786758266610531}. Best is trial 42 with value: 0.04013936428843105.
# [I 2026-08-25 15:57:44,117] Trial 69 finished with value: 0.04379938139391015 and parameters: {'n_estimators': 324, 'max_depth': 7, 'learning_rate': 0.04567665091976845, 'subsample': 0.9404109920278916, 'colsample_bytree': 0.9109857838709801}. Best is trial 42 with value: 0.04013936428843105.
# [I 2026-08-25 15:57:45,314] Trial 70 finished with value: 0.0428833053912159 and parameters: {'n_estimators': 719, 'max_depth': 7, 'learning_rate': 0.08985266008517209, 'subsample': 0.9823371066902039, 'colsample_bytree': 0.8548680722354774}. Best is trial 42 with value: 0.04013936428843105.
# [I 2026-08-25 15:57:46,715] Trial 71 finished with value: 0.04202371564881307 and parameters: {'n_estimators': 442, 'max_depth': 8, 'learning_rate': 0.06098774181756648, 'subsample': 0.9588452572302255, 'colsample_bytree': 0.8433725525648167}. Best is trial 42 with value: 0.04013936428843105.
# [I 2026-08-25 15:57:48,389] Trial 72 finished with value: 0.047594246568122694 and parameters: {'n_estimators': 882, 'max_depth': 8, 'learning_rate': 0.05619373501986064, 'subsample': 0.968926401152199, 'colsample_bytree': 0.9297814856863535}. Best is trial 42 with value: 0.04013936428843105.
# [I 2026-08-25 15:57:49,546] Trial 73 finished with value: 0.047380617003202334 and parameters: {'n_estimators': 400, 'max_depth': 8, 'learning_rate': 0.1075129950397195, 'subsample': 0.6336950407576767, 'colsample_bytree': 0.7501250352360938}. Best is trial 42 with value: 0.04013936428843105.
# [I 2026-08-25 15:57:50,980] Trial 74 finished with value: 0.04175690997443679 and parameters: {'n_estimators': 844, 'max_depth': 6, 'learning_rate': 0.07823399610673197, 'subsample': 0.9241130229858072, 'colsample_bytree': 0.8299987580861496}. Best is trial 42 with value: 0.04013936428843105.
# [I 2026-08-25 15:57:55,119] Trial 75 finished with value: 0.041117038882475754 and parameters: {'n_estimators': 661, 'max_depth': 9, 'learning_rate': 0.01124781512322625, 'subsample': 0.9500778215901214, 'colsample_bytree': 0.7855268947172249}. Best is trial 42 with value: 0.04013936428843105.
# [I 2026-08-25 15:57:59,612] Trial 76 finished with value: 0.04308516171456884 and parameters: {'n_estimators': 584, 'max_depth': 9, 'learning_rate': 0.011620662074515162, 'subsample': 0.8898902118172827, 'colsample_bytree': 0.7888128660356041}. Best is trial 42 with value: 0.04013936428843105.
# [I 2026-08-25 15:58:02,388] Trial 77 finished with value: 0.04444704509094461 and parameters: {'n_estimators': 500, 'max_depth': 9, 'learning_rate': 0.02465982205309935, 'subsample': 0.9997891840321583, 'colsample_bytree': 0.7759610587127693}. Best is trial 42 with value: 0.04013936428843105.
# [I 2026-08-25 15:58:06,948] Trial 78 finished with value: 0.045781484821620526 and parameters: {'n_estimators': 776, 'max_depth': 10, 'learning_rate': 0.013495910841929689, 'subsample': 0.9813063378936802, 'colsample_bytree': 0.8660118451071447}. Best is trial 42 with value: 0.04013936428843105.
# [I 2026-08-25 15:58:10,174] Trial 79 finished with value: 0.04482242297995577 and parameters: {'n_estimators': 644, 'max_depth': 9, 'learning_rate': 0.01868014525849929, 'subsample': 0.9470982387895366, 'colsample_bytree': 0.8863747181296423}. Best is trial 42 with value: 0.04013936428843105.
# [I 2026-08-25 15:58:11,074] Trial 80 finished with value: 0.04827701498288661 and parameters: {'n_estimators': 588, 'max_depth': 3, 'learning_rate': 0.04901483693468199, 'subsample': 0.9347680095977168, 'colsample_bytree': 0.9522193080535}. Best is trial 42 with value: 0.04013936428843105.
# [I 2026-08-25 15:58:12,531] Trial 81 finished with value: 0.04334284696698079 and parameters: {'n_estimators': 678, 'max_depth': 8, 'learning_rate': 0.06329243844296935, 'subsample': 0.9621679838761774, 'colsample_bytree': 0.8032851808781327}. Best is trial 42 with value: 0.04013936428843105.
# [I 2026-08-25 15:58:14,657] Trial 82 finished with value: 0.045409201847986774 and parameters: {'n_estimators': 982, 'max_depth': 9, 'learning_rate': 0.03761267009884083, 'subsample': 0.9153710670365384, 'colsample_bytree': 0.8159774692939217}. Best is trial 42 with value: 0.04013936428843105.
# [I 2026-08-25 15:58:16,786] Trial 83 finished with value: 0.043731689924647474 and parameters: {'n_estimators': 559, 'max_depth': 8, 'learning_rate': 0.02870315347844103, 'subsample': 0.951165112341049, 'colsample_bytree': 0.7532297485959047}. Best is trial 42 with value: 0.04013936428843105.
# [I 2026-08-25 15:58:18,101] Trial 84 finished with value: 0.0424864173895748 and parameters: {'n_estimators': 486, 'max_depth': 9, 'learning_rate': 0.08230305152804224, 'subsample': 0.9694687944100676, 'colsample_bytree': 0.7897353587085142}. Best is trial 42 with value: 0.04013936428843105.
# [I 2026-08-25 15:58:21,456] Trial 85 finished with value: 0.04485331292703955 and parameters: {'n_estimators': 938, 'max_depth': 8, 'learning_rate': 0.014533771458426681, 'subsample': 0.9809874714355531, 'colsample_bytree': 0.8547544266341649}. Best is trial 42 with value: 0.04013936428843105.
# [I 2026-08-25 15:58:22,793] Trial 86 finished with value: 0.04300409002462402 and parameters: {'n_estimators': 926, 'max_depth': 7, 'learning_rate': 0.1171735273901014, 'subsample': 0.9365727321436534, 'colsample_bytree': 0.776879495655866}. Best is trial 42 with value: 0.04013936428843105.
# [I 2026-08-25 15:58:24,836] Trial 87 finished with value: 0.042364937833756104 and parameters: {'n_estimators': 880, 'max_depth': 10, 'learning_rate': 0.05033970712197945, 'subsample': 0.9040786629139534, 'colsample_bytree': 0.9038459017672872}. Best is trial 42 with value: 0.04013936428843105.
# [I 2026-08-25 15:58:26,731] Trial 88 finished with value: 0.04790662500616034 and parameters: {'n_estimators': 978, 'max_depth': 4, 'learning_rate': 0.044201887639321584, 'subsample': 0.9612266743622985, 'colsample_bytree': 0.7221702436025356}. Best is trial 42 with value: 0.04013936428843105.
# [I 2026-08-25 15:58:32,249] Trial 89 finished with value: 0.042012288062273404 and parameters: {'n_estimators': 825, 'max_depth': 9, 'learning_rate': 0.010437806267259292, 'subsample': 0.9884092209189567, 'colsample_bytree': 0.8409596308165453}. Best is trial 42 with value: 0.04013936428843105.
# [I 2026-08-25 15:58:33,994] Trial 90 finished with value: 0.04213704047530579 and parameters: {'n_estimators': 919, 'max_depth': 8, 'learning_rate': 0.0659773213267106, 'subsample': 0.8311901026694852, 'colsample_bytree': 0.8214383511164235}. Best is trial 42 with value: 0.04013936428843105.
# [I 2026-08-25 15:58:35,430] Trial 91 finished with value: 0.03972621813348572 and parameters: {'n_estimators': 844, 'max_depth': 5, 'learning_rate': 0.0750912414835386, 'subsample': 0.9213306259756079, 'colsample_bytree': 0.8250609703672335}. Best is trial 91 with value: 0.03972621813348572.
# [I 2026-08-25 15:58:36,912] Trial 92 finished with value: 0.04387326233841628 and parameters: {'n_estimators': 669, 'max_depth': 5, 'learning_rate': 0.05698805723439955, 'subsample': 0.925335311731943, 'colsample_bytree': 0.8754752288037643}. Best is trial 91 with value: 0.03972621813348572.
# [I 2026-08-25 15:58:38,283] Trial 93 finished with value: 0.0449800500431997 and parameters: {'n_estimators': 850, 'max_depth': 5, 'learning_rate': 0.09773133957230638, 'subsample': 0.8857008620801192, 'colsample_bytree': 0.8124021730299589}. Best is trial 91 with value: 0.03972621813348572.
# [I 2026-08-25 15:58:39,824] Trial 94 finished with value: 0.046600782787815355 and parameters: {'n_estimators': 952, 'max_depth': 5, 'learning_rate': 0.07111345224523466, 'subsample': 0.9561805775093253, 'colsample_bytree': 0.7970049845249149}. Best is trial 91 with value: 0.03972621813348572.
# [I 2026-08-25 15:58:41,212] Trial 95 finished with value: 0.04349816020826185 and parameters: {'n_estimators': 885, 'max_depth': 6, 'learning_rate': 0.07635870080528544, 'subsample': 0.9432609791568711, 'colsample_bytree': 0.7629207515285044}. Best is trial 91 with value: 0.03972621813348572.
# [I 2026-08-25 15:58:42,456] Trial 96 finished with value: 0.05049862324287662 and parameters: {'n_estimators': 729, 'max_depth': 4, 'learning_rate': 0.08894816364206537, 'subsample': 0.8628242326770439, 'colsample_bytree': 0.5467578263942201}. Best is trial 91 with value: 0.03972621813348572.
# [I 2026-08-25 15:58:44,369] Trial 97 finished with value: 0.044552162451408445 and parameters: {'n_estimators': 618, 'max_depth': 9, 'learning_rate': 0.06017690683116328, 'subsample': 0.971601094073684, 'colsample_bytree': 0.8325804752305049}. Best is trial 91 with value: 0.03972621813348572.
# [I 2026-08-25 15:58:45,890] Trial 98 finished with value: 0.042666293131737296 and parameters: {'n_estimators': 997, 'max_depth': 8, 'learning_rate': 0.10378808388258012, 'subsample': 0.7596346011372976, 'colsample_bytree': 0.7415836093836558}. Best is trial 91 with value: 0.03972621813348572.
# [I 2026-08-25 15:58:48,226] Trial 99 finished with value: 0.039527122493180085 and parameters: {'n_estimators': 785, 'max_depth': 10, 'learning_rate': 0.06819083020089889, 'subsample': 0.918910318988281, 'colsample_bytree': 0.8468679627392736}. Best is trial 99 with value: 0.039527122493180085.
# Best MAE:    0.039527122493180085
# Best params: {'n_estimators': 785, 'max_depth': 10, 'learning_rate': 0.06819083020089889, 'subsample': 0.918910318988281, 'colsample_bytree': 0.8468679627392736}
# Running CV for metrics...
# CV complete.
# Fitting final model on train dataset (last obs: 2026-08-16)...
# Fit complete.
# Model written to: s3://environment-monitor/syria/atamah_camp/ml/model_atamah_camp_2026-08-25.pkl
# Generating forecast...
# Forecast written to: s3://environment-monitor/syria/atamah_camp/ml/forecast_atamah_camp_2026-08-25.parquet
# Writing metrics...
# Metrics written to: s3://environment-monitor/syria/atamah_camp/ml/metrics_atamah_camp_2026-08-25.json

# %%
h = 12
preds_from_model = forecast_ts.predict_xgb(forecast_horizon=h)
# Out:
# Loading model from: s3://environment-monitor/syria/atamah_camp/ml/model_atamah_camp_2026-08-25.pkl
# Forecast written to: s3://environment-monitor/syria/atamah_camp/ml/forecast_atamah_camp_2026-08-25.parquet

# %%
import pandas as pd
import plotly.graph_objects as go

# ---------------------------------------------------------------
# REPLACE WITH YOUR DATA
# final_df: your historical dataframe with columns ds, y, unique_id
# forecast: your forecast dataframe with columns ds, XGBRegressor, unique_id
# ---------------------------------------------------------------

final_df = input_df.copy()
forecast = preds_from_model.copy()
series_ids    = sorted(final_df["unique_id"].unique())
spec_indices  = ['ndvi', 'bsi', 'ndmi', 'nbr']
series_labels = [s.upper() for s in spec_indices]  # ['NDVI', 'BSI', 'NDMI', 'NBR']

series_ids = sorted(final_df["unique_id"].unique())
colors     = ["#685A22", "#D85A30", "#2C968F", "#D4537E"]
n          = len(series_ids)

fig = go.Figure()

# Add 3 traces per series: train, test, forecast
for i, sid in enumerate(series_ids):
    color   = colors[i % len(colors)]
    visible = (i == 0)

    h           = final_df[final_df["unique_id"] == sid].sort_values("ds")
    f           = forecast[forecast["unique_id"] == sid].sort_values("ds")
    fcast_start = f["ds"].min()

    train = h[h["ds"] <  fcast_start]
    test  = h[h["ds"] >= fcast_start]

    fig.add_trace(go.Scatter(
        x=train["ds"], y=train["y"],
        mode="lines", name="Train",
        line=dict(color=color, width=2),
        visible=visible,
        hovertemplate="<b>%{x}</b><br>%{y:.2f}<extra>Train</extra>"
    ))

    fig.add_trace(go.Scatter(
        x=test["ds"], y=test["y"],
        mode="lines", name="Test",
        line=dict(color=color, width=3),
        opacity=0.4,
        visible=visible,
        hovertemplate="<b>%{x}</b><br>%{y:.2f}<extra>Test</extra>"
    ))

    fig.add_trace(go.Scatter(
        x=f["ds"], y=f["XGBRegressor"],
        mode="lines", name="Forecast",
        line=dict(color=color, width=2, dash="dot"),
        visible=visible,
        hovertemplate="<b>%{x}</b><br>%{y:.2f}<extra>Forecast</extra>"
    ))

# Build dropdown buttons — 3 traces per series
buttons = []
for i, sid in enumerate(series_ids):
    visible = [False] * (n * 3)
    visible[i * 3]     = True  # train
    visible[i * 3 + 1] = True  # test
    visible[i * 3 + 2] = True  # forecast

    f           = forecast[forecast["unique_id"] == sid].sort_values("ds")
    fcast_start = f["ds"].min().strftime("%Y-%m-%d")

    buttons.append(dict(
        label=series_labels[i],
        method="update",
        args=[
            {"visible": visible},
            {
                "shapes": [dict(
                    type="line", x0=fcast_start, x1=fcast_start,
                    y0=0, y1=1, yref="paper",
                    line=dict(color="#ccc", width=1, dash="dash")
                )],
                "annotations": [dict(
                    x=fcast_start, y=0.98, yref="paper",
                    xanchor="left", yanchor="top",
                    text="forecast start", showarrow=False,
                    font=dict(size=10, color="#aaa")
                )]
            }
        ]
    ))

fig.update_layout(
    updatemenus=[dict(
        buttons=buttons,
        direction="down",
        x=0, xanchor="left",
        y=1.12, yanchor="top",
        showactive=True,
        bgcolor="white",
        bordercolor="#ccc",
        font=dict(size=13)
    )],
    hovermode="x unified",
    plot_bgcolor="white",
    paper_bgcolor="white",
    margin=dict(t=80, r=20, b=60, l=60),
    xaxis=dict(showgrid=True, gridcolor="#ebebeb", showline=True, linecolor="#d0d0cc"),
    yaxis=dict(showgrid=True, gridcolor="#ebebeb", showline=True, linecolor="#d0d0cc"),
    legend=dict(orientation="h", x=0, y=-0.15, font=dict(size=12), bgcolor="rgba(0,0,0,0)"),
)

fig.show()
fig.write_html(f"{aoi_name}_forecast_chart.html", include_plotlyjs="cdn")
print(f"Saved to {aoi_name}_forecast_chart.html")
# Out:
# Saved to atamah_camp_forecast_chart.html
